# %% [markdown]
# # Đề kiểm tra lập trình nhập môn phân tích dữ liệu và học sâu

# %% [markdown]
# ### Sinh viên không được phép sử dụng internet
# ### Sinh viên sau khi làm bài xong xuất ra file PDF đồng thời nộp lên Fit-lab và push lên git-hub
# ### Sinh viên làm bắt đầu làm bài từ 15h40 - 18h00

# %% [markdown]
# **Họ và Tên: NGUYỄN LÊ THIÊN PHÚC**
#
# **MSSV: 2174802010888**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
#Bước 1: Load data
def load_dataset():
    X, y = load_iris(return_X_y=True)
    X = X[y!=2]
    y = y[y!=2]
    return X,y
#Điền ở đây
X,y = load_dataset()
print(X.shape ,y.shape)
# Out:
# (100, 4) (100,)

# %% [markdown]
# Kết quả: (100, 4) (100,)

# %%
#Trực quan hóa dữ liệu data
#Điền code ở đây
plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Iris Dataset')
plt.show()

# %% [markdown]
# Kết quả

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Bước 2: Định nghĩa mô hình hồi quy logistic bằng PyTorch
class LogisticRegressTorch(nn.Module):
    def __init__(self, n_features):
        super(LogisticRegressTorch, self).__init__()
        #Điền ở đây theo comment                # tạo một lớp tuyến tính (nn.Linear) với n_features đầu vào và 1 đầu ra
        self.linear = nn.Linear(n_features, 1)
    def forward(self, x):
        return torch.sigmoid(self.linear(x))

# %%
# Bước 3: Định nghĩa lớp dữ liệu
class IrisTorch(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)

    def __len__(self):
        return  len(self.X)          #trả về số lượng mẫu trong tập dữ liệu (số lượng hàng trong self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]            #trả về một cặp đặc trưng và nhãn tương ứng với chỉ số idx

# %%
# Tạo dữ liệu
dataset = IrisTorch(X, y)

# %%
# Bước 4: Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra bằng cách chia ngẫu nhiên 70,30.
train_size = 0.7                                             #70%
test_size = 0.3                                             #30%
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
# Tạo DataLoader
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader =  DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Bước 5: Định nghĩa criterion và optimizer
n_features = X.shape[1]
model = LogisticRegressTorch(n_features)
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters())

# %%
# Huấn luyện mô hình
n_epochs = 200
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(n_epochs):
    model.train()
    train_loss = 0.0
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)

    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)

    # Đánh giá trên tập kiểm tra
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item() * inputs.size(0)

            predicted = (outputs >= 0.5).float()
            total += targets.size(0)
            correct += (predicted == targets).sum().item()

    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)

    accuracy = correct / total
    test_accuracies.append(accuracy)

    print(f'Epoch {epoch+1}/{n_epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/200, Train Loss: 1.3400, Test Loss: 1.4403, Test Accuracy: 0.4667
# Epoch 2/200, Train Loss: 1.3260, Test Loss: 1.4204, Test Accuracy: 0.4667
# Epoch 3/200, Train Loss: 1.3082, Test Loss: 1.4061, Test Accuracy: 0.4667
# Epoch 4/200, Train Loss: 1.2954, Test Loss: 1.3947, Test Accuracy: 0.4667
# Epoch 5/200, Train Loss: 1.2845, Test Loss: 1.3783, Test Accuracy: 0.4667
# Epoch 6/200, Train Loss: 1.2694, Test Loss: 1.3616, Test Accuracy: 0.4667
# Epoch 7/200, Train Loss: 1.2542, Test Loss: 1.3452, Test Accuracy: 0.4667
# Epoch 8/200, Train Loss: 1.2391, Test Loss: 1.3284, Test Accuracy: 0.4667
# Epoch 9/200, Train Loss: 1.2234, Test Loss: 1.3069, Test Accuracy: 0.4667
# Epoch 10/200, Train Loss: 1.2041, Test Loss: 1.2912, Test Accuracy: 0.4667
# Epoch 11/200, Train Loss: 1.1902, Test Loss: 1.2809, Test Accuracy: 0.4667
# Epoch 12/200, Train Loss: 1.1801, Test Loss: 1.2630, Test Accuracy: 0.4667
# Epoch 13/200, Train Loss: 1.1642, Test Loss: 1.2503, Test Accuracy: 0.4667
# Epoch 14/200, Train Loss: 1.1522, Test Loss: 1.2327, Test Accuracy: 0.4667
# Epoch 15/200, Train Loss: 1.1367, Test Loss: 1.2229, Test Accuracy: 0.4667
# Epoch 16/200, Train Loss: 1.1278, Test Loss: 1.2128, Test Accuracy: 0.4667
# Epoch 17/200, Train Loss: 1.1183, Test Loss: 1.2001, Test Accuracy: 0.4667
# Epoch 18/200, Train Loss: 1.1069, Test Loss: 1.1903, Test Accuracy: 0.4667
# Epoch 19/200, Train Loss: 1.0974, Test Loss: 1.1735, Test Accuracy: 0.4667
# Epoch 20/200, Train Loss: 1.0823, Test Loss: 1.1592, Test Accuracy: 0.4667
# Epoch 21/200, Train Loss: 1.0695, Test Loss: 1.1476, Test Accuracy: 0.4667
# Epoch 22/200, Train Loss: 1.0591, Test Loss: 1.1382, Test Accuracy: 0.4667
# Epoch 23/200, Train Loss: 1.0499, Test Loss: 1.1220, Test Accuracy: 0.4667
# Epoch 24/200, Train Loss: 1.0356, Test Loss: 1.1108, Test Accuracy: 0.4667
# Epoch 25/200, Train Loss: 1.0249, Test Loss: 1.0925, Test Accuracy: 0.4667
# Epoch 26/200, Train Loss: 1.0087, Test Loss: 1.0815, Test Accuracy: 0.4667
# Epoch 27/200, Train Loss: 0.9985, Test Loss: 1.0664, Test Accuracy: 0.4667
# Epoch 28/200, Train Loss: 0.9851, Test Loss: 1.0556, Test Accuracy: 0.4667
# Epoch 29/200, Train Loss: 0.9750, Test Loss: 1.0423, Test Accuracy: 0.4667
# Epoch 30/200, Train Loss: 0.9632, Test Loss: 1.0321, Test Accuracy: 0.4667
# Epoch 31/200, Train Loss: 0.9539, Test Loss: 1.0220, Test Accuracy: 0.4667
# Epoch 32/200, Train Loss: 0.9445, Test Loss: 1.0092, Test Accuracy: 0.4667
# Epoch 33/200, Train Loss: 0.9332, Test Loss: 0.9998, Test Accuracy: 0.4667
# Epoch 34/200, Train Loss: 0.9245, Test Loss: 0.9878, Test Accuracy: 0.4667
# Epoch 102/200, Train Loss: 0.5626, Test Loss: 0.5869, Test Accuracy: 0.4667
# Epoch 103/200, Train Loss: 0.5627, Test Loss: 0.5851, Test Accuracy: 0.4667
# Epoch 104/200, Train Loss: 0.5612, Test Loss: 0.5841, Test Accuracy: 0.4667
# Epoch 105/200, Train Loss: 0.5603, Test Loss: 0.5824, Test Accuracy: 0.4667
# Epoch 106/200, Train Loss: 0.5589, Test Loss: 0.5807, Test Accuracy: 0.4667
# Epoch 107/200, Train Loss: 0.5575, Test Loss: 0.5796, Test Accuracy: 0.4667
# Epoch 108/200, Train Loss: 0.5566, Test Loss: 0.5780, Test Accuracy: 0.4667
# Epoch 109/200, Train Loss: 0.5552, Test Loss: 0.5756, Test Accuracy: 0.4667
# Epoch 110/200, Train Loss: 0.5534, Test Loss: 0.5741, Test Accuracy: 0.4667
# Epoch 111/200, Train Loss: 0.5523, Test Loss: 0.5746, Test Accuracy: 0.4667
# Epoch 112/200, Train Loss: 0.5524, Test Loss: 0.5738, Test Accuracy: 0.4667
# Epoch 113/200, Train Loss: 0.5516, Test Loss: 0.5722, Test Accuracy: 0.4667
# Epoch 114/200, Train Loss: 0.5503, Test Loss: 0.5703, Test Accuracy: 0.4667
# Epoch 115/200, Train Loss: 0.5487, Test Loss: 0.5683, Test Accuracy: 0.4667
# Epoch 116/200, Train Loss: 0.5473, Test Loss: 0.5676, Test Accuracy: 0.4667
# Epoch 117/200, Train Loss: 0.5465, Test Loss: 0.5656, Test Accuracy: 0.4667
# Epoch 118/200, Train Loss: 0.5450, Test Loss: 0.5648, Test Accuracy: 0.4667
# Epoch 119/200, Train Loss: 0.5443, Test Loss: 0.5641, Test Accuracy: 0.4667
# Epoch 120/200, Train Loss: 0.5438, Test Loss: 0.5640, Test Accuracy: 0.4667
# Epoch 121/200, Train Loss: 0.5435, Test Loss: 0.5638, Test Accuracy: 0.4667
# Epoch 122/200, Train Loss: 0.5431, Test Loss: 0.5619, Test Accuracy: 0.4667
# Epoch 123/200, Train Loss: 0.5416, Test Loss: 0.5596, Test Accuracy: 0.4667
# Epoch 124/200, Train Loss: 0.5399, Test Loss: 0.5579, Test Accuracy: 0.4667
# Epoch 125/200, Train Loss: 0.5386, Test Loss: 0.5572, Test Accuracy: 0.4667
# Epoch 126/200, Train Loss: 0.5379, Test Loss: 0.5560, Test Accuracy: 0.5000
# Epoch 127/200, Train Loss: 0.5370, Test Loss: 0.5555, Test Accuracy: 0.5000
# Epoch 128/200, Train Loss: 0.5365, Test Loss: 0.5549, Test Accuracy: 0.5000
# Epoch 129/200, Train Loss: 0.5358, Test Loss: 0.5536, Test Accuracy: 0.5333
# Epoch 130/200, Train Loss: 0.5348, Test Loss: 0.5513, Test Accuracy: 0.5667
# Epoch 131/200, Train Loss: 0.5331, Test Loss: 0.5498, Test Accuracy: 0.6000
# Epoch 132/200, Train Loss: 0.5319, Test Loss: 0.5481, Test Accuracy: 0.6333
# Epoch 133/200, Train Loss: 0.5307, Test Loss: 0.5471, Test Accuracy: 0.6333
# Epoch 134/200, Train Loss: 0.5298, Test Loss: 0.5461, Test Accuracy: 0.6333
# Epoch 135/200, Train Loss: 0.5291, Test Loss: 0.5461, Test Accuracy: 0.6333
# Epoch 136/200, Train Loss: 0.5288, Test Loss: 0.5457, Test Accuracy: 0.6333
# Epoch 137/200, Train Loss: 0.5283, Test Loss: 0.5446, Test Accuracy: 0.6333
# Epoch 138/200, Train Loss: 0.5275, Test Loss: 0.5441, Test Accuracy: 0.6333
# Epoch 139/200, Train Loss: 0.5269, Test Loss: 0.5436, Test Accuracy: 0.6333
# Epoch 140/200, Train Loss: 0.5264, Test Loss: 0.5431, Test Accuracy: 0.6333
# Epoch 141/200, Train Loss: 0.5258, Test Loss: 0.5416, Test Accuracy: 0.6667
# Epoch 142/200, Train Loss: 0.5247, Test Loss: 0.5407, Test Accuracy: 0.7000
# Epoch 143/200, Train Loss: 0.5239, Test Loss: 0.5398, Test Accuracy: 0.7333
# Epoch 144/200, Train Loss: 0.5232, Test Loss: 0.5388, Test Accuracy: 0.7667
# Epoch 145/200, Train Loss: 0.5224, Test Loss: 0.5384, Test Accuracy: 0.7667
# Epoch 146/200, Train Loss: 0.5219, Test Loss: 0.5370, Test Accuracy: 0.7667
# Epoch 147/200, Train Loss: 0.5208, Test Loss: 0.5357, Test Accuracy: 0.8333
# Epoch 148/200, Train Loss: 0.5198, Test Loss: 0.5343, Test Accuracy: 0.8333
# Epoch 149/200, Train Loss: 0.5188, Test Loss: 0.5334, Test Accuracy: 0.8667
# Epoch 150/200, Train Loss: 0.5181, Test Loss: 0.5326, Test Accuracy: 0.8667
# Epoch 151/200, Train Loss: 0.5174, Test Loss: 0.5319, Test Accuracy: 0.8667
# Epoch 152/200, Train Loss: 0.5167, Test Loss: 0.5307, Test Accuracy: 0.9333
# Epoch 153/200, Train Loss: 0.5158, Test Loss: 0.5295, Test Accuracy: 0.9333
# Epoch 154/200, Train Loss: 0.5150, Test Loss: 0.5284, Test Accuracy: 0.9333
# Epoch 155/200, Train Loss: 0.5142, Test Loss: 0.5279, Test Accuracy: 0.9333
# Epoch 156/200, Train Loss: 0.5137, Test Loss: 0.5279, Test Accuracy: 0.9333
# Epoch 157/200, Train Loss: 0.5133, Test Loss: 0.5267, Test Accuracy: 0.9333
# Epoch 158/200, Train Loss: 0.5125, Test Loss: 0.5263, Test Accuracy: 0.9333
# Epoch 159/200, Train Loss: 0.5120, Test Loss: 0.5248, Test Accuracy: 0.9333
# Epoch 160/200, Train Loss: 0.5110, Test Loss: 0.5237, Test Accuracy: 0.9333
# Epoch 161/200, Train Loss: 0.5102, Test Loss: 0.5230, Test Accuracy: 0.9333
# Epoch 162/200, Train Loss: 0.5095, Test Loss: 0.5223, Test Accuracy: 0.9333
# Epoch 163/200, Train Loss: 0.5089, Test Loss: 0.5213, Test Accuracy: 0.9667
# Epoch 164/200, Train Loss: 0.5083, Test Loss: 0.5216, Test Accuracy: 0.9333
# Epoch 165/200, Train Loss: 0.5080, Test Loss: 0.5206, Test Accuracy: 0.9667
# Epoch 166/200, Train Loss: 0.5072, Test Loss: 0.5199, Test Accuracy: 0.9667
# Epoch 167/200, Train Loss: 0.5066, Test Loss: 0.5191, Test Accuracy: 0.9667
# Epoch 168/200, Train Loss: 0.5060, Test Loss: 0.5181, Test Accuracy: 1.0000
# Epoch 169/200, Train Loss: 0.5052, Test Loss: 0.5177, Test Accuracy: 1.0000
# Epoch 170/200, Train Loss: 0.5047, Test Loss: 0.5167, Test Accuracy: 1.0000
# Epoch 171/200, Train Loss: 0.5040, Test Loss: 0.5166, Test Accuracy: 1.0000
# Epoch 172/200, Train Loss: 0.5036, Test Loss: 0.5157, Test Accuracy: 1.0000
# Epoch 173/200, Train Loss: 0.5029, Test Loss: 0.5150, Test Accuracy: 1.0000
# Epoch 174/200, Train Loss: 0.5023, Test Loss: 0.5143, Test Accuracy: 1.0000
# Epoch 175/200, Train Loss: 0.5017, Test Loss: 0.5134, Test Accuracy: 1.0000
# Epoch 176/200, Train Loss: 0.5010, Test Loss: 0.5125, Test Accuracy: 1.0000
# Epoch 177/200, Train Loss: 0.5004, Test Loss: 0.5116, Test Accuracy: 1.0000
# Epoch 178/200, Train Loss: 0.4997, Test Loss: 0.5110, Test Accuracy: 1.0000
# Epoch 179/200, Train Loss: 0.4991, Test Loss: 0.5104, Test Accuracy: 1.0000
# Epoch 180/200, Train Loss: 0.4986, Test Loss: 0.5098, Test Accuracy: 1.0000
# Epoch 181/200, Train Loss: 0.4980, Test Loss: 0.5090, Test Accuracy: 1.0000
# Epoch 182/200, Train Loss: 0.4974, Test Loss: 0.5079, Test Accuracy: 1.0000
# Epoch 183/200, Train Loss: 0.4967, Test Loss: 0.5071, Test Accuracy: 1.0000
# Epoch 184/200, Train Loss: 0.4961, Test Loss: 0.5066, Test Accuracy: 1.0000
# Epoch 185/200, Train Loss: 0.4956, Test Loss: 0.5065, Test Accuracy: 1.0000
# Epoch 186/200, Train Loss: 0.4951, Test Loss: 0.5052, Test Accuracy: 1.0000
# Epoch 187/200, Train Loss: 0.4944, Test Loss: 0.5049, Test Accuracy: 1.0000
# Epoch 188/200, Train Loss: 0.4939, Test Loss: 0.5045, Test Accuracy: 1.0000
# Epoch 189/200, Train Loss: 0.4934, Test Loss: 0.5037, Test Accuracy: 1.0000
# Epoch 190/200, Train Loss: 0.4928, Test Loss: 0.5032, Test Accuracy: 1.0000
# Epoch 191/200, Train Loss: 0.4923, Test Loss: 0.5028, Test Accuracy: 1.0000
# Epoch 192/200, Train Loss: 0.4918, Test Loss: 0.5024, Test Accuracy: 1.0000
# Epoch 193/200, Train Loss: 0.4912, Test Loss: 0.5023, Test Accuracy: 1.0000
# Epoch 194/200, Train Loss: 0.4908, Test Loss: 0.5018, Test Accuracy: 1.0000
# Epoch 195/200, Train Loss: 0.4902, Test Loss: 0.5012, Test Accuracy: 1.0000
# Epoch 196/200, Train Loss: 0.4897, Test Loss: 0.5004, Test Accuracy: 1.0000
# Epoch 197/200, Train Loss: 0.4891, Test Loss: 0.4996, Test Accuracy: 1.0000
# Epoch 198/200, Train Loss: 0.4885, Test Loss: 0.4990, Test Accuracy: 1.0000
# Epoch 199/200, Train Loss: 0.4880, Test Loss: 0.4985, Test Accuracy: 1.0000
# Epoch 200/200, Train Loss: 0.4874, Test Loss: 0.4979, Test Accuracy: 1.0000

# %%
# Vẽ biểu đồ loss và accuracy
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss vs Epochs')
plt.show()

plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epochs')
plt.show()

# %% [markdown]
# #Kết quả:

# %% [markdown]
# ![image.png](attachment:image.png)
